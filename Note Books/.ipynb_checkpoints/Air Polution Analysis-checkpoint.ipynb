# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../Data/updated_pollution_dataset.csv")

# %%
df
# Out:
#       Temperature  Humidity  PM2.5   PM10   NO2   SO2    CO  \
# 0            29.8      59.1    5.2   17.9  18.9   9.2  1.72
# 1            28.3      75.6    2.3   12.2  30.8   9.7  1.64
# 2            23.1      74.7   26.7   33.8  24.4  12.6  1.63
# 3            27.1      39.1    6.1    6.3  13.5   5.3  1.15
# 4            26.5      70.7    6.9   16.0  21.9   5.6  1.01
# ...           ...       ...    ...    ...   ...   ...   ...
# 4995         40.6      74.1  116.0  126.7  45.5  25.7  2.11
# 4996         28.1      96.9    6.9   25.0  25.3  10.8  1.54
# 4997         25.9      78.2   14.2   22.1  34.8   7.8  1.63
# 4998         25.3      44.4   21.4   29.0  23.7   5.7  0.89
# 4999         24.1      77.9   81.7   94.3  23.2  10.5  1.38
#
#       Proximity_to_Industrial_Areas  Population_Density Air Quality
# 0                               6.3                 319    Moderate
# 1                               6.0                 611    Moderate
# ...

# %%
df.describe()
# Out:
#        Temperature     Humidity        PM2.5         PM10          NO2  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean     30.029020    70.056120    20.142140    30.218360    26.412100
# std       6.720661    15.863577    24.554546    27.349199     8.895356
# min      13.400000    36.000000     0.000000    -0.200000     7.400000
# 25%      25.100000    58.300000     4.600000    12.300000    20.100000
# 50%      29.000000    69.800000    12.000000    21.700000    25.300000
# 75%      34.000000    80.300000    26.100000    38.100000    31.900000
# max      58.600000   128.100000   295.000000   315.800000    64.900000
#
#                SO2           CO  Proximity_to_Industrial_Areas  \
# count  5000.000000  5000.000000                    5000.000000
# mean     10.014820     1.500354                       8.425400
# std       6.750303     0.546027                       3.610944
# min      -6.200000     0.650000                       2.500000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Temperature                    5000 non-null   float64
#  1   Humidity                       5000 non-null   float64
#  2   PM2.5                          5000 non-null   float64
#  3   PM10                           5000 non-null   float64
#  4   NO2                            5000 non-null   float64
#  5   SO2                            5000 non-null   float64
#  6   CO                             5000 non-null   float64
#  7   Proximity_to_Industrial_Areas  5000 non-null   float64
#  8   Population_Density             5000 non-null   int64
#  9   Air Quality                    5000 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 390.8+ KB

# %%
corr_matrix = df.iloc[:, :-1].corr()
# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 8))

# Create the heatmap
cax = ax.imshow(corr_matrix, cmap='RdYlBu', vmin=-1, vmax=1)

# Add colorbar
fig.colorbar(cax)

# Set ticks and labels
ax.set_xticks(np.arange(len(corr_matrix.columns)))
ax.set_yticks(np.arange(len(corr_matrix.columns)))
ax.set_xticklabels(corr_matrix.columns, rotation=45)
ax.set_yticklabels(corr_matrix.columns)

# Add values in cells (Annotations)
for i in range(len(corr_matrix.columns)):
    for j in range(len(corr_matrix.columns)):
        text = ax.text(j, i, f"{corr_matrix.iloc[i, j]:.2f}",
                       ha="center", va="center", color="black")

plt.title("Correlation Matrix", fontsize=16)
plt.tight_layout()
plt.show()

# %%
df["Air Quality"].value_counts()
# Out:
# Air Quality
# Good         2000
# Moderate     1500
# Poor         1000
# Hazardous     500
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(5, 2, figsize=(12, 18))
axes = axes.flatten()   # Convert 2D array → 1D

for ax, col in zip(axes, df.iloc[:, :-1].columns):
    ax.hist(df[col], bins=10)
    ax.set_title(col)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(5, 2, figsize=(12, 18))
axes = axes.flatten()   # Convert 2D array → 1D

for ax, col in zip(axes, df.iloc[:, :-1].columns):
    ax.boxplot(df[col])
    ax.set_title(col)

plt.tight_layout()
plt.show()

# %%
df1 = df.iloc[:, :-1]
df2 = pd.DataFrame(df["Air Quality"].map({
    'Poor': 0,
    'Moderate': 1,
    'Good': 2,
    'Hazardous': 3
}))
df3 = pd.concat([df1, df2], axis=1)
df3
# Out:
#       Temperature  Humidity  PM2.5   PM10   NO2   SO2    CO  \
# 0            29.8      59.1    5.2   17.9  18.9   9.2  1.72
# 1            28.3      75.6    2.3   12.2  30.8   9.7  1.64
# 2            23.1      74.7   26.7   33.8  24.4  12.6  1.63
# 3            27.1      39.1    6.1    6.3  13.5   5.3  1.15
# 4            26.5      70.7    6.9   16.0  21.9   5.6  1.01
# ...           ...       ...    ...    ...   ...   ...   ...
# 4995         40.6      74.1  116.0  126.7  45.5  25.7  2.11
# 4996         28.1      96.9    6.9   25.0  25.3  10.8  1.54
# 4997         25.9      78.2   14.2   22.1  34.8   7.8  1.63
# 4998         25.3      44.4   21.4   29.0  23.7   5.7  0.89
# 4999         24.1      77.9   81.7   94.3  23.2  10.5  1.38
#
#       Proximity_to_Industrial_Areas  Population_Density  Air Quality
# 0                               6.3                 319            1
# 1                               6.0                 611            1
# ...

# %%
df3.corr()
# Out:
#                                Temperature  Humidity     PM2.5      PM10  \
# Temperature                       1.000000  0.466456  0.323840  0.425690
# Humidity                          0.466456  1.000000  0.273366  0.359156
# PM2.5                             0.323840  0.273366  1.000000  0.973005
# PM10                              0.425690  0.359156  0.973005  1.000000
# NO2                               0.591969  0.491977  0.333004  0.439916
# SO2                               0.568082  0.459804  0.299582  0.401849
# CO                                0.685258  0.567540  0.395179  0.518895
# Proximity_to_Industrial_Areas    -0.589564 -0.479646 -0.315766 -0.425018
# Population_Density                0.481692  0.411630  0.278957  0.365734
# Air Quality                      -0.152046 -0.148279 -0.069126 -0.106942
#
#                                     NO2       SO2        CO  \
# Temperature                    0.591969  0.568082  0.685258
# ...

# %%
fig, ax = plt.subplots()
ax.scatter(df['Proximity_to_Industrial_Areas'], df['PM2.5'], alpha=0.4)
ax.set_xlabel("Distance from Industrial Area (km)")
ax.set_ylabel("PM2.5")
# Out:
# Text(0, 0.5, 'PM2.5')

# %%
from sklearn.model_selection import train_test_split
X = df.iloc[:, :-1]
Y = df["Air Quality"].map({
    'Poor': 0,
    'Moderate': 1,
    'Good': 2,
    'Hazardous': 3
})
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
y_train
# Out:
# 4227    3
# 4676    2
# 800     0
# 3671    2
# 4193    2
#        ..
# 4426    1
# 466     1
# 3092    0
# 3772    2
# 860     3
# Name: Air Quality, Length: 4000, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(x_train, y_train)
# Out:
# C:\Users\srini\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
log_reg.score(x_test, y_test)
# Out:
# 0.851

# %%
from sklearn.metrics import confusion_matrix
y_pred = log_reg.predict(x_train)
cm = confusion_matrix(y_train, y_pred)
print(cm)
# Out:
# [[ 561  163    2   88]
#  [  91 1072   42    1]
#  [   0   23 1568    0]
#  [ 157   10    0  222]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=['Good', 'Moderate', 'Poor', 'Hazardous']
)

disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.svm import SVC

svc = SVC(kernel="rbf")
svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
svc.score(x_test, y_test)
# Out:
# 0.758

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(max_depth=10, ccp_alpha=0.0001, criterion="gini")
tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0001, max_depth=10)

# %%
tree.score(x_test, y_test)
# Out:
# 0.936

# %%
from sklearn.metrics import confusion_matrix
y_pred = tree.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[160   9   0  17]
#  [ 13 278   3   0]
#  [  0   1 408   0]
#  [ 21   0   0  90]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=['Good', 'Moderate', 'Poor', 'Hazardous']
)

disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

random_tree = RandomForestClassifier(n_estimators=100, random_state=42)
random_tree.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
random_tree.score(x_test, y_test)
# Out:
# 0.961

# %%
random_tree.score(x_train, y_train)
# Out:
# 1.0

# %%
importance = pd.DataFrame({
    'Feature': x_train.columns,
    'Importance': random_tree.feature_importances_
}).sort_values(by='Importance', ascending=False)

print(importance.head())
# Out:
#                          Feature  Importance
# 6                             CO    0.334678
# 7  Proximity_to_Industrial_Areas    0.287712
# 4                            NO2    0.099142
# 5                            SO2    0.092587
# 0                    Temperature    0.073776

# %%
import joblib
joblib.dump(log_reg, "../Models/logistic_regression.pkl")
joblib.dump(random_tree, "../Models/random_forest.pkl")
joblib.dump(svc, "../Models/SVM.pkl")
joblib.dump(tree, "../Models/decision_tree.pkl")
# Out:
# ['../Models/decision_tree.pkl']

# %%
from sklearn.metrics import confusion_matrix
y_pred = random_tree.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[169   9   0   8]
#  [  9 285   0   0]
#  [  0   0 409   0]
#  [ 13   0   0  98]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=['Good', 'Moderate', 'Poor', 'Hazardous']
)

disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# %%
df3.columns
# Out:
# Index(['Temperature', 'Humidity', 'PM2.5', 'PM10', 'NO2', 'SO2', 'CO',
#        'Proximity_to_Industrial_Areas', 'Population_Density', 'Air Quality'],
#       dtype='object')

# %%
df3.drop(['PM2.5', 'PM10'], axis=1, inplace=True)
X = df3
Y = df3["Air Quality"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
X_train
# Out:
#       Temperature  Humidity   NO2   SO2    CO  Proximity_to_Industrial_Areas  \
# 4227         38.8      92.5  32.8   8.3  2.19                            3.9
# 4676         26.3      54.1  25.1   4.5  0.95                           10.1
# 800          37.2     111.3  31.9  18.5  2.12                            7.7
# 3671         17.5      57.2  25.6   3.1  1.03                           11.6
# 4193         26.7      54.8  15.8   4.5  1.25                           11.8
# ...           ...       ...   ...   ...   ...                            ...
# 4426         30.0      59.7  22.1   7.4  1.39                            5.1
# 466          27.7      54.0  24.6  11.1  1.27                            7.8
# 3092         24.2      67.6  24.2   9.6  1.91                            6.2
# 3772         21.4      76.4  12.4   3.4  0.96                           16.3
# 860          34.4     103.1  54.4  23.6  3.37                            3.7
#
#       Population_Density  Air Quality
# ...

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train, Y_train)
# Out:
# C:\Users\srini\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
log_reg.score(X_test, Y_test)
# Out:
# 0.998

# %%
from sklearn.svm import SVC

svc = SVC(kernel="rbf")
svc.fit(X_train, Y_train)
# Out:
# SVC()

# %%
svc.score(X_test, Y_test)
# Out:
# 0.733

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier()
tree.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
tree.score(X_test, Y_test)
# Out:
# 1.0

# %%
from sklearn.ensemble import RandomForestClassifier

random_tree = RandomForestClassifier(n_estimators=100, random_state=42)
random_tree.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
random_tree.score(X_test, Y_test)
# Out:
# 1.0

# %%
random_tree.score(X_train, Y_train)
# Out:
# 1.0
